# %% [markdown]
# **Import Libraries**

# %%
import logging
import os
import warnings

import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import tensorflow_hub as hub

from datetime import datetime
from keras.preprocessing import image
from PIL import Image
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve
from tensorflow.keras import layers

warnings.filterwarnings('ignore')
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %% [markdown]
# **Import Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
datasetdir = '/content/drive/MyDrive/Bird'
os.chdir(datasetdir)

# %%
# Load file locations
df_info = pd.read_excel('dataset_information.xlsx', sheet_name = 'images.txt')

#Load class information
df_classes = pd.read_excel('dataset_information.xlsx', sheet_name = 'classes.txt')

#Read Train Test Split details
df_train_test = pd.read_csv('train_test_split.csv')

# %%
df_classes.head(10)
# Out:
#    child_class_id                                  class_description
# 0               1                            Ducks, Geese, and Swans
# 1               2                          Grouse, Quail, and Allies
# 2               3                                              Loons
# 3               4                                             Grebes
# 4               5                                             Storks
# 5               6  Frigatebirds, Boobies, Cormorants, Darters, an...
# 6               7               Pelicans, Herons, Ibises, and Allies
# 7               8                   Hawks, Kites, Eagles, and Allies
# 8               9                              Caracaras and Falcons
# 9              10                                   Cranes and Rails

# %%
#Split the class and imange name
df_image = df_info.join(df_info['image_location'].str.split('/',expand=True).rename(columns={0:'class_id',1:'image_name'}))

# %%
df_image.tail(10)
# Out:
#                                    image_id  ...                            image_name
# 48552  ffef2e23-edd7-4221-88a8-074ac0773d77  ...  ffef2e23edd7422188a8074ac0773d77.jpg
# 48553  ffef9325-d321-4129-825d-2d7dddeeb824  ...  ffef9325d3214129825d2d7dddeeb824.jpg
# 48554  fff0b2c3-5ab3-4c64-b160-a77398fe5a46  ...  fff0b2c35ab34c64b160a77398fe5a46.jpg
# 48555  fff1d97b-2ac3-410d-8c6d-7430470bb951  ...  fff1d97b2ac3410d8c6d7430470bb951.jpg
# 48556  fff3ec39-07d4-4600-b753-12013066277f  ...  fff3ec3907d44600b75312013066277f.jpg
# 48557  fff86e8b-795f-400a-91e8-565bbb8c453a  ...  fff86e8b795f400a91e8565bbb8c453a.jpg
# 48558  fff926d7-ccad-4788-839e-97af2dd99372  ...  fff926d7ccad4788839e97af2dd99372.jpg
# 48559  fffa33ef-a765-408d-8d66-6efc7f504c71  ...  fffa33efa765408d8d666efc7f504c71.jpg
# 48560  ffff0d87-bc84-4ef2-a47e-a4bfa48502ce  ...  ffff0d87bc844ef2a47ea4bfa48502ce.jpg
# 48561  fffff3a5-2a75-47d0-887f-03871e3f9a37  ...  fffff3a52a7547d0887f03871e3f9a37.jpg
#
# [10 rows x 4 columns]

# %%
#Convert the string column to INT to chop leading zeroes
df_image['class_id'] = df_image['class_id'].astype(int)

# %%
#Join the information and class dataframe 
df_bird = pd.merge(df_image, df_classes, left_on='class_id', right_on='child_class_id', how='left').drop('child_class_id', axis=1)

# %%
df_bird.head(10)
# Out:
#                                image_id  ...                               class_description
# 0  0000139e-21dc-4d0c-bfe1-4cae3c85c829  ...                                    Oak Titmouse
# 1  0000d9fc-4e02-4c06-a0af-a55cfb16b12b  ...                                        Ovenbird
# 2  00019306-9d83-4334-b255-a447742edce3  ...                                Savannah Sparrow
# 3  0001afd4-99a1-4a67-b940-d419413e23b3  ...              Eared Grebe (Nonbreeding/juvenile)
# 4  000332b8-997c-4540-9647-2f0a8495aecf  ...                                  Eastern Phoebe
# 5  000343bd-5215-49ba-ab9c-7c97a70ac1a5  ...           Yellow-crowned Night-Heron (Immature)
# 6  0004ff8d-0cc8-47ee-94ba-43352a8b9eb4  ...                               Florida Scrub-Jay
# 7  0007181f-a727-4481-ad89-591200c61b9d  ...                                Savannah Sparrow
# 8  00071e20-8156-4bd8-b5ca-6445c2560ee5  ...  Yellow-headed Blackbird (Female/Immature Male)
# 9  0007acfc-c0e6-4393-9ab6-02215a82ef63  ...                            Herring Gull (Adult)
#
# [10 rows x 5 columns]

# %%
#Find the count of bird class in case only specific classes need to be to the model
df_bird.groupby(['class_id'])['class_id'].count().reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
#      class_id  count
# 523       979    120
# 446       902    120
# 275       672    120
# 80        397    120
# 400       856    120
# ..        ...    ...
# 550      1006     25
# 299       755     24
# 33        341     23
# 267       664     21
# 519       975     13
#
# [555 rows x 2 columns]

# %%
#Find the count of bird class in case only specific classes need to be to the model
df_classcounts = df_bird.groupby(['class_id'])['class_id'].count().reset_index(name='count').sort_values(['count'], ascending=False)

# %%
#Selected only specific labels
target_class = df_classcounts[(df_classcounts['count']>=90) & (df_classcounts['count']<=120)]['class_id'].values

df_bird['FILTERED_LABEL'] = (df_bird.class_id.isin(target_class)).astype('int')

# %%
df_classcounts['count'].values
# Out:
# array([120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119,
#        119, 119, 119, 119, 119, 119, 118, 118, 118, 118, 118, 118, 118,
#        118, 118, 118, 118, 118, 118, 118, 117, 117, 117, 117, 117, 117,
#        117, 117, 116, 116, 116, 116, 116, 116, 116, 116, 116, 116, 116,
#        116, 116, 116, 116, 115, 115, 115, 115, 114, 114, 114, 114, 113,
#        113, 113, 113, 113, 113, 113, 113, 113, 112, 112, 112, 112, 112,
#        111, 111, 111, 111, 111, 111, 111, 110, 110, 110, 110, 110, 109,
#        109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 108, 108, 108,
#        108, 108, 108, 108, 108, 107, 107, 107, 106, 106, 106, 106, 106,
#        106, 106, 105, 105, 105, 105, 105, 104, 104, 104, 104, 104, 103,
#        103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 102, 102,
#        102, 101, 101, 101, 101, 101, 101, 101, 100, 100,  99,  99,  99,
#         99,  99,  98,  98,  98,  98,  98,  98,  98,  98,  98,  98,  97,
#         97,  97,  97,  97,  96,  96,  96,  96,  96,  95,  95,  95,  94,
#         94,  94,  94,  94,  94,  93,  93,  93,  93,  93,  93,  92,  92,
#         92,  92,  92,  91,  91,  91,  90,  90,  90,  90,  89,  89,  89,
#         89,  89,  88,  88,  88,  88,  87,  87,  87,  87,  87,  87,  87,
#         86,  86,  86,  86,  86,  86,  86,  85,  85,  85,  84,  84,  83,
#         83,  83,  83,  82,  82,  82,  82,  82,  82,  82,  81,  81,  81,
#         81,  81,  80,  80,  80,  80,  80,  80,  80,  80,  79,  79,  79,
#         78,  78,  78,  78,  78,  78,  77,  77,  77,  77,  77,  77,  77,
#         76,  76,  76,  76,  76,  76,  76,  76,  75,  75,  75,  75,  75,
#         75,  75,  75,  75,  75,  74,  74,  74,  74,  74,  74,  74,  73,
#         73,  73,  72,  72,  72,  72,  72,  72,  72,  72,  72,  71,  71,
#         71,  71,  71,  70,  70,  70,  70,  70,  70,  70,  70,  69,  69,
#         69,  67,  67,  67,  67,  67,  66,  66,  66,  66,  66,  66,  66,
#         66,  66,  65,  65,  65,  65,  65,  65,  65,  65,  64,  64,  64,
#         64,  64,  64,  64,  64,  64,  63,  63,  63,  63,  63,  62,  62,
#         62,  62,  62,  61,  61,  61,  61,  60,  60,  60,  60,  59,  59,
#         59,  59,  59,  59,  58,  58,  58,  58,  57,  57,  57,  56,  56,
#         55,  55,  55,  55,  55,  54,  54,  54,  54,  54,  54,  54,  53,
#         53,  53,  53,  53,  53,  52,  51,  51,  50,  50,  50,  50,  49,
#         49,  49,  49,  48,  48,  48,  48,  47,  47,  47,  47,  47,  47,
#         46,  46,  46,  45,  45,  45,  44,  44,  44,  44,  44,  42,  42,
#         42,  41,  41,  41,  41,  40,  39,  39,  39,  39,  37,  37,  37,
#         36,  36,  35,  35,  34,  33,  33,  32,  32,  32,  31,  31,  31,
#         31,  30,  28,  27,  25,  24,  23,  21,  13])

# %%
df_target =  df_bird[df_bird['FILTERED_LABEL']==1]
df_target.shape
# Out:
# (31330, 6)

# %%
df_target['class_id'] = df_target['class_id'].astype(str)
df_target['image_location'] = df_target['image_location'].astype(str)

# %% [markdown]
# **Prepare Training and Validation Set**

# %%
df_train_test.head(10)
# Out:
#                                   image  train
# 0  0000139e-21dc-4d0c-bfe1-4cae3c85c829      0
# 1  0000d9fc-4e02-4c06-a0af-a55cfb16b12b      0
# 2  00019306-9d83-4334-b255-a447742edce3      0
# 3  0001afd4-99a1-4a67-b940-d419413e23b3      1
# 4  000332b8-997c-4540-9647-2f0a8495aecf      0
# 5  000343bd-5215-49ba-ab9c-7c97a70ac1a5      0
# 6  0004ff8d-0cc8-47ee-94ba-43352a8b9eb4      0
# 7  0007181f-a727-4481-ad89-591200c61b9d      1
# 8  00071e20-8156-4bd8-b5ca-6445c2560ee5      1
# 9  0007acfc-c0e6-4393-9ab6-02215a82ef63      0

# %%
#Join the target and train test dataframe 
df_target = pd.merge(df_target, df_train_test, left_on='image_id', right_on='image', how='left').drop('image', axis=1)

# %% [markdown]
# **Train set**

# %%
df_train =  df_target[df_target['train']==1]
df_train.shape
# Out:
# (15507, 7)

# %%
X_train = df_train['image_location']
y_train = df_train['class_id']

# %% [markdown]
# **Validation and Test set**

# %%
df_valtest =  df_target[df_target['train']==0]
df_valtest.shape
# Out:
# (15823, 7)

# %%
X_val, X_test, y_val, y_test = train_test_split(df_valtest['image_location'], df_valtest['class_id'], test_size=0.25, random_state=44)
TotalImages = len(X_train) + len(X_val) + len(X_test)
print("Number of images for training: ", len(X_train))
print("Number of images for validation: ", len(X_val))
print("Number of images for testing: ", len(X_test))
print("Total Images in Train Test Val Set is: ",TotalImages )
# Out:
# Number of images for training:  15507
# Number of images for validation:  11867
# Number of images for testing:  3956
# Total Images in Train Test Val Set is:  31330

# %% [markdown]
# **Add directory path**

# %%
X_train = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_train]
X_val = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_val]
X_test = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_test]

X_train[:3]
# Out:
# ['/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0900/0007181fa7274481ad89591200c61b9d.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0651/000948ee8c1940bb840372c665e7ffc3.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0947/000c3c44dd8c4efe949e3adfd766d719.jpg']

# %% [markdown]
# **Show sample image**

# %%
plt.imshow(Image.open(X_train[1]))

# %% [markdown]
# **Encode the Target Labels**

# %%
y_train.shape
# Out:
# (15507,)

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(y_train)
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %%
lb.classes_
# Out:
# array(['1001', '1002', '1003', '299', '314', '315', '316', '317', '319',
#        '320', '322', '328', '332', '333', '335', '338', '340', '343',
#        '347', '348', '350', '351', '352', '353', '354', '355', '356',
#        '357', '358', '363', '366', '368', '371', '373', '374', '375',
#        '379', '380', '381', '382', '395', '397', '400', '446', '448',
#        '450', '451', '453', '458', '469', '470', '473', '477', '480',
#        '481', '482', '483', '484', '485', '486', '489', '490', '491',
#        '495', '498', '499', '501', '503', '504', '508', '509', '510',
#        '511', '512', '513', '514', '515', '516', '519', '520', '521',
#        '522', '523', '525', '527', '528', '529', '530', '533', '536',
#        '538', '539', '541', '542', '543', '544', '549', '550', '551',
#        '553', '554', '555', '557', '558', '559', '560', '561', '607',
#        '613', '616', '640', '642', '643', '647', '651', '654', '655',
#        '656', '657', '662', '667', '668', '669', '672', '673', '674',
#        '676', '681', '700', '746', '747', '748', '749', '750', '753',
#        '756', '757', '758', '760', '761', '762', '764', '766', '768',
#        '769', '770', '771', '772', '773', '774', '775', '776', '777',
#        '778', '779', '780', '781', '783', '784', '785', '786', '788',
#        '790', '793', '794', '795', '796', '797', '798', '802', '803',
#        '804', '810', '811', '812', '813', '814', '819', '822', '823',
#        '824', '827', '830', '831', '832', '834', '835', '836', '840',
#        '842', '843', '844', '847', '848', '849', '850', '851', '852',
#        '853', '856', '857', '859', '860', '862', '864', '865', '866',
#        '867', '868', '871', '872', '873', '874', '875', '876', '877',
#        '878', '879', '881', '883', '884', '885', '886', '888', '889',
#        '892', '894', '895', '897', '898', '899', '900', '902', '903',
#        '904', '907', '908', '910', '911', '912', '913', '914', '922',
#        '923', '924', '925', '926', '928', '929', '930', '932', '934',
#        '935', '937', '938', '939', '944', '946', '947', '948', '949',
#        '950', '952', '955', '957', '958', '960', '962', '963', '964',
#        '965', '968', '973', '974', '976', '979', '980', '987', '989',
#        '990', '993', '995', '997'], dtype='<U4')

# %%
y_train_bin = lb.transform(y_train)
y_val_bin = lb.transform(y_val)
y_test_bin = lb.transform(y_test)
y_train_bin.shape, y_val_bin.shape, y_test_bin.shape
# Out:
# ((15507, 283), (11867, 283), (3956, 283))

# %% [markdown]
# **Define the Image Size for the model**

# %%
IMG_SIZE = 224 #Image size
CHANNELS = 3 # Keep RGB color channels 
N_CLASSES = len(lb.classes_) #Total no.of classes

# %% [markdown]
# **Map the filename and label to create Dataset**

# %%
def parse_img_label(filename, label):

    # Read an image from a file
    image_string = tf.io.read_file(filename)

    # Decode it into a  vector
    image_decoded = tf.image.decode_jpeg(image_string, channels=CHANNELS)

    # Resize it to fixed shape
    image_resized = tf.image.resize(image_decoded, [IMG_SIZE, IMG_SIZE])

    # Normalize the image
    image_normalized = image_resized / 255.0
    
    return image_normalized, label

# %%
BATCH_SIZE = 512 
AUTOTUNE = tf.data.experimental.AUTOTUNE # Adapt preprocessing and prefetching dynamically
SHUFFLE_BUFFER_SIZE = 256

# %%
def gen_dataset(filenames, labels, is_training=True):

 
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    dataset = dataset.map(parse_img_label, num_parallel_calls=AUTOTUNE)
    
    if is_training == True:
        # This is a small dataset, only load it once, and keep it in memory.
        dataset = dataset.cache()
        # Shuffle the data each buffer size
        dataset = dataset.shuffle(buffer_size=SHUFFLE_BUFFER_SIZE)
        
    
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(buffer_size=AUTOTUNE)
    
    return dataset

# %%
train_ds = gen_dataset(X_train, y_train_bin)
val_ds = gen_dataset(X_val, y_val_bin)
test_ds = gen_dataset(X_test,y_test_bin)

# %%
for f, l in train_ds.take(1):
    print("Shape of features array:", f.numpy().shape)
    print("Shape of labels array:", l.numpy().shape)
# Out:
# Shape of features array: (512, 224, 224, 3)
# Shape of labels array: (512, 283)

# %% [markdown]
# **Prepare Transfer Learning Model - HUB MobileNet V2 140_224**

# %%
feature_extractor_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4"
feature_extractor_layer = hub.KerasLayer(feature_extractor_url,
                                         input_shape=(IMG_SIZE,IMG_SIZE,CHANNELS))

# %%
feature_extractor_layer.trainable = False

# %%
model = tf.keras.Sequential([
    feature_extractor_layer,
    layers.Dense(4096, activation='relu', name='hidden_layer1'),
    layers.Dropout(0.2),
    layers.Dense(2048, activation='relu', name='hidden_layer2'),
    layers.Dropout(0.2),
    layers.Dense(1024, activation='relu', name='hidden_layer3'),
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu', name='hidden_layer4'),
    layers.Dense(N_CLASSES, activation='sigmoid', name='output')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1792)              4363712
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 4096)              7344128
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 2048)              8390656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 512)               524800
# _________________________________________________________________
# output (Dense)               (None, 283)               145179
# =================================================================
# Total params: 22,866,651
# Trainable params: 18,502,939
# Non-trainable params: 4,363,712
# _________________________________________________________________

# %% [markdown]
# **Define MACRO F1 Score for multi-class**

# %%
def macro_f1(y, y_hat, thresh=0.5):
    y_pred = tf.cast(tf.greater(y_hat, thresh), tf.float32)
    tp = tf.cast(tf.math.count_nonzero(y_pred * y, axis=0), tf.float32)
    fp = tf.cast(tf.math.count_nonzero(y_pred * (1 - y), axis=0), tf.float32)
    fn = tf.cast(tf.math.count_nonzero((1 - y_pred) * y, axis=0), tf.float32)
    f1 = 2*tp / (2*tp + fn + fp + 1e-16)
    macro_f1 = tf.reduce_mean(f1)
    return macro_f1

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=5e-4),
    loss=tf.keras.metrics.binary_crossentropy,
     metrics=[macro_f1, 'accuracy'] )

# %%
batch_size = 256
history = model.fit(train_ds,batch_size=batch_size, epochs=50, validation_data=val_ds,validation_batch_size= batch_size)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 227s 7s/step - loss: 0.2238 - macro_f1: 0.0020 - accuracy: 0.0043 - val_loss: 0.0269 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0036
# Epoch 2/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0271 - macro_f1: 0.0000e+00 - accuracy: 0.0041 - val_loss: 0.0242 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0034
# Epoch 3/50
# 31/31 [==============================] - 134s 4s/step - loss: 0.0248 - macro_f1: 0.0000e+00 - accuracy: 0.0053 - val_loss: 0.0235 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0174
# Epoch 4/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0240 - macro_f1: 0.0000e+00 - accuracy: 0.0093 - val_loss: 0.0227 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0329
# Epoch 5/50
# 31/31 [==============================] - 133s 4s/step - loss: 0.0230 - macro_f1: 0.0000e+00 - accuracy: 0.0198 - val_loss: 0.0210 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0640
# Epoch 6/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0211 - macro_f1: 0.0000e+00 - accuracy: 0.0471 - val_loss: 0.0185 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.1175
# Epoch 7/50
# 31/31 [==============================] - 132s 4s/step - loss: 0.0186 - macro_f1: 4.8807e-04 - accuracy: 0.0993 - val_loss: 0.0160 - val_macro_f1: 0.0078 - val_accuracy: 0.1681
# Epoch 8/50
# 31/31 [==============================] - 135s 4s/step - loss: 0.0162 - macro_f1: 0.0132 - accuracy: 0.1605 - val_loss: 0.0142 - val_macro_f1: 0.0292 - val_accuracy: 0.2480
# Epoch 9/50
# 31/31 [==============================] - 134s 4s/step - loss: 0.0144 - macro_f1: 0.0416 - accuracy: 0.2369 - val_loss: 0.0129 - val_macro_f1: 0.0665 - val_accuracy: 0.3201
# Epoch 10/50
# 31/31 [==============================] - 133s 4s/step - loss: 0.0130 - macro_f1: 0.0740 - accuracy: 0.2999 - val_loss: 0.0119 - val_macro_f1: 0.1181 - val_accuracy: 0.3662
# Epoch 11/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0117 - macro_f1: 0.1183 - accuracy: 0.3674 - val_loss: 0.0111 - val_macro_f1: 0.1647 - val_accuracy: 0.4085
# Epoch 12/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0107 - macro_f1: 0.1697 - accuracy: 0.4301 - val_loss: 0.0105 - val_macro_f1: 0.2046 - val_accuracy: 0.4369
# Epoch 13/50
# 31/31 [==============================] - 133s 4s/step - loss: 0.0099 - macro_f1: 0.2093 - accuracy: 0.4671 - val_loss: 0.0101 - val_macro_f1: 0.2470 - val_accuracy: 0.4607
# Epoch 14/50
# 31/31 [==============================] - 129s 4s/step - loss: 0.0091 - macro_f1: 0.2602 - accuracy: 0.5301 - val_loss: 0.0098 - val_macro_f1: 0.2752 - val_accuracy: 0.4846
# Epoch 15/50
# 31/31 [==============================] - 129s 4s/step - loss: 0.0084 - macro_f1: 0.2996 - accuracy: 0.5623 - val_loss: 0.0096 - val_macro_f1: 0.2974 - val_accuracy: 0.4969
# Epoch 16/50
# 31/31 [==============================] - 133s 4s/step - loss: 0.0078 - macro_f1: 0.3395 - accuracy: 0.5958 - val_loss: 0.0094 - val_macro_f1: 0.3180 - val_accuracy: 0.5096
# Epoch 17/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0073 - macro_f1: 0.3704 - accuracy: 0.6320 - val_loss: 0.0093 - val_macro_f1: 0.3284 - val_accuracy: 0.5185
# Epoch 18/50
# 31/31 [==============================] - 130s 4s/step - loss: 0.0068 - macro_f1: 0.3958 - accuracy: 0.6622 - val_loss: 0.0092 - val_macro_f1: 0.3362 - val_accuracy: 0.5258
# Epoch 19/50
# 31/31 [==============================] - 131s 4s/step - loss: 0.0064 - macro_f1: 0.4261 - accuracy: 0.6849 - val_loss: 0.0091 - val_macro_f1: 0.3547 - val_accuracy: 0.5368
# Epoch 20/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0059 - macro_f1: 0.4566 - accuracy: 0.7235 - val_loss: 0.0091 - val_macro_f1: 0.3715 - val_accuracy: 0.5424
# Epoch 21/50
# 31/31 [==============================] - 124s 4s/step - loss: 0.0055 - macro_f1: 0.4858 - accuracy: 0.7482 - val_loss: 0.0092 - val_macro_f1: 0.3668 - val_accuracy: 0.5416
# Epoch 22/50
# 31/31 [==============================] - 127s 4s/step - loss: 0.0050 - macro_f1: 0.5151 - accuracy: 0.7742 - val_loss: 0.0092 - val_macro_f1: 0.3802 - val_accuracy: 0.5467
# Epoch 23/50
# 31/31 [==============================] - 132s 4s/step - loss: 0.0046 - macro_f1: 0.5361 - accuracy: 0.7958 - val_loss: 0.0094 - val_macro_f1: 0.3809 - val_accuracy: 0.5438
# Epoch 24/50
# 31/31 [==============================] - 135s 4s/step - loss: 0.0043 - macro_f1: 0.5616 - accuracy: 0.8186 - val_loss: 0.0095 - val_macro_f1: 0.3943 - val_accuracy: 0.5491
# Epoch 25/50
# 31/31 [==============================] - 135s 4s/step - loss: 0.0040 - macro_f1: 0.5881 - accuracy: 0.8358 - val_loss: 0.0095 - val_macro_f1: 0.3914 - val_accuracy: 0.5553
# Epoch 26/50
# 31/31 [==============================] - 135s 4s/step - loss: 0.0037 - macro_f1: 0.6031 - accuracy: 0.8548 - val_loss: 0.0096 - val_macro_f1: 0.4001 - val_accuracy: 0.5585
# Epoch 27/50
# 31/31 [==============================] - 129s 4s/step - loss: 0.0033 - macro_f1: 0.6217 - accuracy: 0.8734 - val_loss: 0.0097 - val_macro_f1: 0.4060 - val_accuracy: 0.5653
# Epoch 28/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0030 - macro_f1: 0.6530 - accuracy: 0.8933 - val_loss: 0.0100 - val_macro_f1: 0.3969 - val_accuracy: 0.5638
# Epoch 29/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0028 - macro_f1: 0.6692 - accuracy: 0.9033 - val_loss: 0.0102 - val_macro_f1: 0.3933 - val_accuracy: 0.5591
# Epoch 30/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0026 - macro_f1: 0.6764 - accuracy: 0.9130 - val_loss: 0.0105 - val_macro_f1: 0.3929 - val_accuracy: 0.5555
# Epoch 31/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0024 - macro_f1: 0.6960 - accuracy: 0.9259 - val_loss: 0.0106 - val_macro_f1: 0.3982 - val_accuracy: 0.5535
# Epoch 32/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0023 - macro_f1: 0.6929 - accuracy: 0.9268 - val_loss: 0.0105 - val_macro_f1: 0.4009 - val_accuracy: 0.5605
# Epoch 33/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0021 - macro_f1: 0.7124 - accuracy: 0.9403 - val_loss: 0.0111 - val_macro_f1: 0.4013 - val_accuracy: 0.5565
# Epoch 34/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0019 - macro_f1: 0.7158 - accuracy: 0.9470 - val_loss: 0.0111 - val_macro_f1: 0.4093 - val_accuracy: 0.5605
# Epoch 35/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0018 - macro_f1: 0.7384 - accuracy: 0.9465 - val_loss: 0.0112 - val_macro_f1: 0.4047 - val_accuracy: 0.5573
# Epoch 36/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0016 - macro_f1: 0.7469 - accuracy: 0.9567 - val_loss: 0.0116 - val_macro_f1: 0.4036 - val_accuracy: 0.5559
# Epoch 37/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0016 - macro_f1: 0.7424 - accuracy: 0.9603 - val_loss: 0.0120 - val_macro_f1: 0.4030 - val_accuracy: 0.5561
# Epoch 38/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0014 - macro_f1: 0.7571 - accuracy: 0.9678 - val_loss: 0.0120 - val_macro_f1: 0.4116 - val_accuracy: 0.5646
# Epoch 39/50
# 31/31 [==============================] - 126s 4s/step - loss: 0.0012 - macro_f1: 0.7712 - accuracy: 0.9737 - val_loss: 0.0120 - val_macro_f1: 0.4121 - val_accuracy: 0.5632
# Epoch 40/50
# 31/31 [==============================] - 125s 4s/step - loss: 0.0011 - macro_f1: 0.7748 - accuracy: 0.9778 - val_loss: 0.0122 - val_macro_f1: 0.4119 - val_accuracy: 0.5631
# Epoch 41/50
# 31/31 [==============================] - 125s 4s/step - loss: 9.8396e-04 - macro_f1: 0.7857 - accuracy: 0.9816 - val_loss: 0.0131 - val_macro_f1: 0.4106 - val_accuracy: 0.5606
# Epoch 42/50
# 31/31 [==============================] - 126s 4s/step - loss: 9.6716e-04 - macro_f1: 0.7863 - accuracy: 0.9819 - val_loss: 0.0136 - val_macro_f1: 0.4018 - val_accuracy: 0.5511
# Epoch 43/50
# 31/31 [==============================] - 125s 4s/step - loss: 9.3618e-04 - macro_f1: 0.7831 - accuracy: 0.9827 - val_loss: 0.0130 - val_macro_f1: 0.4119 - val_accuracy: 0.5667
# Epoch 44/50
# 31/31 [==============================] - 126s 4s/step - loss: 7.9403e-04 - macro_f1: 0.7892 - accuracy: 0.9882 - val_loss: 0.0133 - val_macro_f1: 0.4197 - val_accuracy: 0.5709
# Epoch 45/50
# 31/31 [==============================] - 127s 4s/step - loss: 7.2772e-04 - macro_f1: 0.7960 - accuracy: 0.9891 - val_loss: 0.0137 - val_macro_f1: 0.4123 - val_accuracy: 0.5686
# Epoch 46/50
# 31/31 [==============================] - 129s 4s/step - loss: 7.1283e-04 - macro_f1: 0.7960 - accuracy: 0.9884 - val_loss: 0.0135 - val_macro_f1: 0.4147 - val_accuracy: 0.5675
# Epoch 47/50
# 31/31 [==============================] - 129s 4s/step - loss: 6.6533e-04 - macro_f1: 0.8023 - accuracy: 0.9904 - val_loss: 0.0139 - val_macro_f1: 0.4064 - val_accuracy: 0.5663
# Epoch 48/50
# 31/31 [==============================] - 131s 4s/step - loss: 6.3198e-04 - macro_f1: 0.8013 - accuracy: 0.9905 - val_loss: 0.0142 - val_macro_f1: 0.4066 - val_accuracy: 0.5617
# Epoch 49/50
# 31/31 [==============================] - 126s 4s/step - loss: 6.1050e-04 - macro_f1: 0.8039 - accuracy: 0.9908 - val_loss: 0.0141 - val_macro_f1: 0.4155 - val_accuracy: 0.5654
# Epoch 50/50
# 31/31 [==============================] - 127s 4s/step - loss: 5.6615e-04 - macro_f1: 0.8114 - accuracy: 0.9917 - val_loss: 0.0146 - val_macro_f1: 0.4092 - val_accuracy: 0.5611

# %% [markdown]
# **Evaluate the Model**

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 8/8 [==============================] - 34s 4s/step - loss: 0.0151 - macro_f1: 0.4143 - accuracy: 0.5561
# {'accuracy': 0.5561172962188721,
#  'loss': 0.015103967860341072,
#  'macro_f1': 0.41426974534988403}

# %% [markdown]
# **Model Performance**

# %%
mf1 = history.history['macro_f1']
val_mf1 = history.history['val_macro_f1']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(50)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, mf1, label='Training macro f1')
plt.plot(epochs_range, val_mf1, label='Validation macro f1')
plt.legend(loc='lower right')
plt.title('Training and Validation macro f1')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Save the entire model as a SavedModel.
model.save('/content/drive/MyDrive/Bird/model_img104224')

# %% [markdown]
# **Show Predicted Images**

# %%
 results = (model.predict(test_ds) > 0.5).astype('int')

# %%
#Set the directory path to show images
dir_path ='/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/'

#Iterate through predictions to show correct predicted classes
for count in range(len(results[:3000])):
  pred = results[count]
  #print(pred)
  if np.max(pred) == 1:
    pred  = pd.Series(pred)
    pred.index = lb.classes_
    prediction = pred[pred==1].index.values
    pred_label = np.max(prediction)
    if str(pred_label) == df_target['class_id'][count]:
      print('\nActual Class:',df_target['class_id'][count])
      print('\nActual Class_descriptions:',df_target['class_description'][count])
      print('\nPredicted Class:',pred_label)
      
      img_path = dir_path + df_target['image_location'][count]
      style.use('default')
      plt.figure(figsize=(8,4))
      plt.imshow(Image.open(img_path))
      plt.title('\nBird Class\n{}\n'.format(df_target['class_description'][count]), fontsize=9)
      plt.show()
      #plt.imshow(Image.open(X_test[0]))
# Out:
# Actual Class: 776
#
# Actual Class_descriptions: Lazuli Bunting (Adult Male)
#
# Predicted Class: 776
# Actual Class: 539
#
# Actual Class_descriptions: Great Horned Owl
#
# Predicted Class: 539
# Actual Class: 769
#
# Actual Class_descriptions: Chipping Sparrow (Breeding)
#
# Predicted Class: 769
# Actual Class: 382
#
# Actual Class_descriptions: Northern Flicker (Yellow-shafted)
#
# Predicted Class: 382
# Actual Class: 613
#
# Actual Class_descriptions: Wood Duck (Female/Eclipse male)
#
# Predicted Class: 613
# Actual Class: 862
#
# Actual Class_descriptions: Northern Waterthrush
#
# Predicted Class: 862
# Actual Class: 912
#
# Actual Class_descriptions: Common Grackle
#
# Predicted Class: 912
# Actual Class: 777
#
# Actual Class_descriptions: Indigo Bunting (Adult Male)
#
# Predicted Class: 777
# Actual Class: 781
#
# Actual Class_descriptions: Yellow-headed Blackbird (Adult Male)
#
# Predicted Class: 781
# Actual Class: 450
#
# Actual Class_descriptions: Common Tern
#
# Predicted Class: 450
