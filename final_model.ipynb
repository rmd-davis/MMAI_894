# %%
import logging
import os
import warnings

import matplotlib.pyplot as plt
import matplotlib.style as style
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import tensorflow_hub as hub

from datetime import datetime
from keras.preprocessing import image
from PIL import Image
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.calibration import calibration_curve
from tensorflow.keras import layers

warnings.filterwarnings('ignore')
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# %%
from google.colab import drive
drive.mount('/content/drive')
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
datasetdir = '/content/drive/MyDrive/MMAI 894 - DEEP LEARNING/TEAM PROJECT/images_scaled'
os.chdir(datasetdir)

# %%
# Load file locations
df_info = pd.read_excel('/content/drive/MyDrive/MMAI 894 - DEEP LEARNING/TEAM PROJECT/dataset_information.xlsx', sheet_name = 'images.txt')

#Load class information
df_classes = pd.read_excel('/content/drive/MyDrive/MMAI 894 - DEEP LEARNING/TEAM PROJECT/dataset_information.xlsx', sheet_name = 'classes.txt')

# %%
#Split the class and image name
df_image = df_info.join(df_info['image_location'].str.split('/',expand=True).rename(columns={0:'class_id',1:'image_name'}))

# %%
#Convert the string column to INT to chop leading zeroes
df_image['class_id'] = df_image['class_id'].astype(int)

# %%
#Join the information and class dataframe 
df_bird = pd.merge(df_image, df_classes, left_on='class_id', right_on='child_class_id', how='left').drop('child_class_id', axis=1)

# %%
#Find the count of bird class in case only specific classes need to be to the model
DF_classcounts = df_bird.groupby(['class_id'])['class_id'].count().reset_index(name='count').sort_values(['count'], ascending=False)

# %%
DF_classcounts['count'].values
# Out:
# array([120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120, 120,
#        120, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119,
#        119, 119, 119, 119, 119, 119, 118, 118, 118, 118, 118, 118, 118,
#        118, 118, 118, 118, 118, 118, 118, 117, 117, 117, 117, 117, 117,
#        117, 117, 116, 116, 116, 116, 116, 116, 116, 116, 116, 116, 116,
#        116, 116, 116, 116, 115, 115, 115, 115, 114, 114, 114, 114, 113,
#        113, 113, 113, 113, 113, 113, 113, 113, 112, 112, 112, 112, 112,
#        111, 111, 111, 111, 111, 111, 111, 110, 110, 110, 110, 110, 109,
#        109, 109, 109, 109, 109, 109, 109, 109, 109, 109, 108, 108, 108,
#        108, 108, 108, 108, 108, 107, 107, 107, 106, 106, 106, 106, 106,
#        106, 106, 105, 105, 105, 105, 105, 104, 104, 104, 104, 104, 103,
#        103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 103, 102, 102,
#        102, 101, 101, 101, 101, 101, 101, 101, 100, 100,  99,  99,  99,
#         99,  99,  98,  98,  98,  98,  98,  98,  98,  98,  98,  98,  97,
#         97,  97,  97,  97,  96,  96,  96,  96,  96,  95,  95,  95,  94,
#         94,  94,  94,  94,  94,  93,  93,  93,  93,  93,  93,  92,  92,
#         92,  92,  92,  91,  91,  91,  90,  90,  90,  90,  89,  89,  89,
#         89,  89,  88,  88,  88,  88,  87,  87,  87,  87,  87,  87,  87,
#         86,  86,  86,  86,  86,  86,  86,  85,  85,  85,  84,  84,  83,
#         83,  83,  83,  82,  82,  82,  82,  82,  82,  82,  81,  81,  81,
#         81,  81,  80,  80,  80,  80,  80,  80,  80,  80,  79,  79,  79,
#         78,  78,  78,  78,  78,  78,  77,  77,  77,  77,  77,  77,  77,
#         76,  76,  76,  76,  76,  76,  76,  76,  75,  75,  75,  75,  75,
#         75,  75,  75,  75,  75,  74,  74,  74,  74,  74,  74,  74,  73,
#         73,  73,  72,  72,  72,  72,  72,  72,  72,  72,  72,  71,  71,
#         71,  71,  71,  70,  70,  70,  70,  70,  70,  70,  70,  69,  69,
#         69,  67,  67,  67,  67,  67,  66,  66,  66,  66,  66,  66,  66,
#         66,  66,  65,  65,  65,  65,  65,  65,  65,  65,  64,  64,  64,
#         64,  64,  64,  64,  64,  64,  63,  63,  63,  63,  63,  62,  62,
#         62,  62,  62,  61,  61,  61,  61,  60,  60,  60,  60,  59,  59,
#         59,  59,  59,  59,  58,  58,  58,  58,  57,  57,  57,  56,  56,
#         55,  55,  55,  55,  55,  54,  54,  54,  54,  54,  54,  54,  53,
#         53,  53,  53,  53,  53,  52,  51,  51,  50,  50,  50,  50,  49,
#         49,  49,  49,  48,  48,  48,  48,  47,  47,  47,  47,  47,  47,
#         46,  46,  46,  45,  45,  45,  44,  44,  44,  44,  44,  42,  42,
#         42,  41,  41,  41,  41,  40,  39,  39,  39,  39,  37,  37,  37,
#         36,  36,  35,  35,  34,  33,  33,  32,  32,  32,  31,  31,  31,
#         31,  30,  28,  27,  25,  24,  23,  21,  13])

# %% [markdown]
# ## **Target Variables here: all classes with (Number of images) >= 60. Total 453 classes with 43955 images.**

# %%
#Selected only specific labels
target_class = DF_classcounts[(DF_classcounts['count']>=60) & (DF_classcounts['count']<=120)]['class_id'].values

df_bird['FILTERED_LABEL'] = (df_bird.class_id.isin(target_class)).astype('int')

# %%
DF_classcounts[(DF_classcounts['count']>=60) & (DF_classcounts['count']<=120)]['count'].sum()
# Out:
# 43955

# %%
len(target_class)
# Out:
# 453

# %%
df_target =  df_bird[df_bird['FILTERED_LABEL']==1]

# %%
len(df_target)
# Out:
# 43955

# %%
# Move 'class_id' and 'image_location' into string type features 
df_target['class_id'] = df_target['class_id'].astype(str)
df_target['image_location'] = df_target['image_location'].astype(str)

# %%
datasetdir = '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled'
os.chdir(datasetdir)

# %% [markdown]
# **Split the data into train set 60%, validation set 15% and a test set 25%.**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_target['image_location'], df_target['class_id'], test_size=0.25, random_state=44)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=1/5, train_size=4/5, random_state=44)

print("Number of posters for training: ", len(X_train))
print("Number of posters for validation: ", len(X_val))
print("Number of posters for training: ", len(X_test))
# Out:
# Number of posters for training:  26372
# Number of posters for validation:  6594
# Number of posters for training:  10989

# %%
len(X_train) + len(X_val) + len(X_test)
# Out:
# 43955

# %%
len(X_train)/len(df_target)
# Out:
# 0.5999772494596747

# %%
len(X_val)/len(df_target)
# Out:
# 0.150017062905244

# %%
len(X_test)/len(df_target)
# Out:
# 0.25000568763508135

# %%
X_train = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_train]
X_val = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_val]
#X_test = [os.path.join('/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/', str(f)) for f in X_train]
X_train[:5]
# Out:
# ['/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0831/c387c0d6fa14497aaaf1ff3443154e5a.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0613/5e26b456cdda49c1ba8d70069008d833.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0767/931ee5a595d9438fbd8571024045713e.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0914/5ec283f8edeb4abb89307c45dda2ac41.jpg',
#  '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0395/bcb091b457b944a193a5f5d5c2201c35.jpg']

# %%
X_train[1]
# Out:
# '/content/drive/.shortcut-targets-by-id/17pVG9Sy8XzdWBm7-KrdDnpAmGyZRy0Vc/images_scaled/0613/5e26b456cdda49c1ba8d70069008d833.jpg'

# %% [markdown]
# **For simplicity, let's encode our target labels into one-hot encoded labels using preprocessing.LabelBinarizer().**

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(y_train)
lb.fit(y_val)
# Out:
# LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)

# %%
y_train_bin = lb.transform(y_train)
y_val_bin = lb.transform(y_val)
y_test_bin = lb.transform(y_test)

# %% [markdown]
# **Model MobileNet_v2 requires our images to have shape of (224, 224, 3).**

# %%
IMG_SIZE = 224 # Specify height and width of image to match the input format of the model
CHANNELS = 3 # Keep RGB color channels to match the input format of the model
N_CLASSES = len(lb.classes_)

# %% [markdown]
# **Create a function that normalize and resize images inputs to the fixed shape required by the model.**

# %%
def parse_img_label(filename, label):
    
    
    # Read an image from a file
    image_string = tf.io.read_file(filename)

    # Decode it into a dense vector
    image_decoded = tf.image.decode_jpeg(image_string, channels=CHANNELS)

    # Resize it to fixed shape
    image_resized = tf.image.resize(image_decoded, [IMG_SIZE, IMG_SIZE])

    # Normalize it from [0, 255] to [0.0, 1.0]
    image_normalized = image_resized / 255.0
    
    return image_normalized, label

# %%
BATCH_SIZE = 512 
AUTOTUNE = tf.data.experimental.AUTOTUNE # Adapt preprocessing and prefetching dynamically
SHUFFLE_BUFFER_SIZE = 256

# %% [markdown]
# A function to load and parse the dataset

# %%
def gen_dataset(filenames, labels, is_training=True):
    
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    dataset = dataset.map(parse_img_label, num_parallel_calls=AUTOTUNE)
    
    if is_training == True:
        # This is a small dataset, only load it once, and keep it in memory.
        dataset = dataset.cache()
        # Shuffle the data each buffer size
        dataset = dataset.shuffle(buffer_size=SHUFFLE_BUFFER_SIZE)
        
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(buffer_size=AUTOTUNE)
    
    return dataset

# %%
train_ds = gen_dataset(X_train, y_train_bin)
val_ds = gen_dataset(X_val, y_val_bin)
test_ds = gen_dataset(X_test, y_test_bin)

# %%
for f, l in train_ds.take(1):
    print("Shape of features array:", f.numpy().shape)
    print("Shape of labels array:", l.numpy().shape)
# Out:
# Shape of features array: (512, 224, 224, 3)
# Shape of labels array: (512, 453)

# %%
def macro_f1(y, y_hat, thresh=0.5): 
    y_pred = tf.cast(tf.greater(y_hat, thresh), tf.float32)
    tp = tf.cast(tf.math.count_nonzero(y_pred * y, axis=0), tf.float32)
    fp = tf.cast(tf.math.count_nonzero(y_pred * (1 - y), axis=0), tf.float32)
    fn = tf.cast(tf.math.count_nonzero((1 - y_pred) * y, axis=0), tf.float32)
    f1 = 2*tp / (2*tp + fn + fp + 1e-16)
    macro_f1 = tf.reduce_mean(f1)
    return macro_f1

# %%
feature_extractor_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
feature_extractor_layer = hub.KerasLayer(feature_extractor_url, trainable=False,
                                         input_shape=(IMG_SIZE,IMG_SIZE,CHANNELS))

# %% [markdown]
# **In this exercise, let's start only changing the last Dense FC layers of the model "mobilenet_v2_100_224".**

# %%
model = tf.keras.Sequential([
    feature_extractor_layer,
    layers.Dense(2048, activation='relu', name='hidden_layer1'),
    layers.Dropout(0.5),
    layers.Dense(1024, activation='relu', name='hidden_layer2'),
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu', name='hidden_layer3'),
    layers.Dense(N_CLASSES, activation='softmax', name='output')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 2048)              2623488
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 512)               524800
# _________________________________________________________________
# output (Dense)               (None, 453)               232389
# =================================================================
# Total params: 7,736,837
# Trainable params: 5,478,853
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# **Define MACRO F1 Score for multi-class**

# %%
batch_size = 256
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=5e-4),
    loss=tf.keras.metrics.binary_crossentropy,
    metrics=[macro_f1, 'accuracy', tf.keras.metrics.TopKCategoricalAccuracy()])   # Default is k = 5
    
history = model.fit(train_ds, epochs=40,batch_size = batch_size, validation_data = val_ds,
                             validation_batch_size = batch_size)
# Out:
# Epoch 1/40
# 52/52 [==============================] - 2602s 51s/step - loss: 0.2026 - macro_f1: 1.7176e-04 - accuracy: 0.0031 - top_k_categorical_accuracy: 0.0118 - val_loss: 0.0176 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0036 - val_top_k_categorical_accuracy: 0.0133
# Epoch 2/40
# 52/52 [==============================] - 22s 413ms/step - loss: 0.0177 - macro_f1: 0.0000e+00 - accuracy: 0.0025 - top_k_categorical_accuracy: 0.0147 - val_loss: 0.0162 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0039 - val_top_k_categorical_accuracy: 0.0227
# Epoch 3/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0165 - macro_f1: 0.0000e+00 - accuracy: 0.0041 - top_k_categorical_accuracy: 0.0219 - val_loss: 0.0155 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0256 - val_top_k_categorical_accuracy: 0.0805
# Epoch 4/40
# 52/52 [==============================] - 22s 417ms/step - loss: 0.0157 - macro_f1: 0.0000e+00 - accuracy: 0.0155 - top_k_categorical_accuracy: 0.0537 - val_loss: 0.0144 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0466 - val_top_k_categorical_accuracy: 0.1536
# Epoch 5/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0145 - macro_f1: 9.3521e-06 - accuracy: 0.0386 - top_k_categorical_accuracy: 0.1264 - val_loss: 0.0127 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0836 - val_top_k_categorical_accuracy: 0.2669
# Epoch 6/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0129 - macro_f1: 3.5595e-04 - accuracy: 0.0744 - top_k_categorical_accuracy: 0.2288 - val_loss: 0.0113 - val_macro_f1: 7.0753e-04 - val_accuracy: 0.1345 - val_top_k_categorical_accuracy: 0.3743
# Epoch 7/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0115 - macro_f1: 0.0031 - accuracy: 0.1206 - top_k_categorical_accuracy: 0.3307 - val_loss: 0.0102 - val_macro_f1: 0.0117 - val_accuracy: 0.1914 - val_top_k_categorical_accuracy: 0.4630
# Epoch 8/40
# 52/52 [==============================] - 21s 411ms/step - loss: 0.0105 - macro_f1: 0.0123 - accuracy: 0.1702 - top_k_categorical_accuracy: 0.4277 - val_loss: 0.0095 - val_macro_f1: 0.0261 - val_accuracy: 0.2337 - val_top_k_categorical_accuracy: 0.5331
# Epoch 9/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0096 - macro_f1: 0.0296 - accuracy: 0.2175 - top_k_categorical_accuracy: 0.5077 - val_loss: 0.0089 - val_macro_f1: 0.0452 - val_accuracy: 0.2809 - val_top_k_categorical_accuracy: 0.5969
# Epoch 10/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0090 - macro_f1: 0.0481 - accuracy: 0.2602 - top_k_categorical_accuracy: 0.5669 - val_loss: 0.0084 - val_macro_f1: 0.0674 - val_accuracy: 0.3159 - val_top_k_categorical_accuracy: 0.6374
# Epoch 11/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0085 - macro_f1: 0.0677 - accuracy: 0.2963 - top_k_categorical_accuracy: 0.6159 - val_loss: 0.0081 - val_macro_f1: 0.0886 - val_accuracy: 0.3385 - val_top_k_categorical_accuracy: 0.6695
# Epoch 12/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0081 - macro_f1: 0.0931 - accuracy: 0.3365 - top_k_categorical_accuracy: 0.6597 - val_loss: 0.0078 - val_macro_f1: 0.1055 - val_accuracy: 0.3668 - val_top_k_categorical_accuracy: 0.6905
# Epoch 13/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0077 - macro_f1: 0.1125 - accuracy: 0.3662 - top_k_categorical_accuracy: 0.6931 - val_loss: 0.0076 - val_macro_f1: 0.1244 - val_accuracy: 0.3847 - val_top_k_categorical_accuracy: 0.7037
# Epoch 14/40
# 52/52 [==============================] - 22s 413ms/step - loss: 0.0073 - macro_f1: 0.1318 - accuracy: 0.3927 - top_k_categorical_accuracy: 0.7192 - val_loss: 0.0074 - val_macro_f1: 0.1384 - val_accuracy: 0.3999 - val_top_k_categorical_accuracy: 0.7214
# Epoch 15/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0071 - macro_f1: 0.1531 - accuracy: 0.4234 - top_k_categorical_accuracy: 0.7417 - val_loss: 0.0072 - val_macro_f1: 0.1575 - val_accuracy: 0.4202 - val_top_k_categorical_accuracy: 0.7346
# Epoch 16/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0067 - macro_f1: 0.1708 - accuracy: 0.4457 - top_k_categorical_accuracy: 0.7657 - val_loss: 0.0071 - val_macro_f1: 0.1639 - val_accuracy: 0.4324 - val_top_k_categorical_accuracy: 0.7411
# Epoch 17/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0065 - macro_f1: 0.1896 - accuracy: 0.4648 - top_k_categorical_accuracy: 0.7837 - val_loss: 0.0070 - val_macro_f1: 0.1783 - val_accuracy: 0.4412 - val_top_k_categorical_accuracy: 0.7478
# Epoch 18/40
# 52/52 [==============================] - 22s 416ms/step - loss: 0.0063 - macro_f1: 0.2085 - accuracy: 0.4894 - top_k_categorical_accuracy: 0.7978 - val_loss: 0.0069 - val_macro_f1: 0.1927 - val_accuracy: 0.4525 - val_top_k_categorical_accuracy: 0.7551
# Epoch 19/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0061 - macro_f1: 0.2258 - accuracy: 0.5061 - top_k_categorical_accuracy: 0.8104 - val_loss: 0.0068 - val_macro_f1: 0.2037 - val_accuracy: 0.4616 - val_top_k_categorical_accuracy: 0.7577
# Epoch 20/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0059 - macro_f1: 0.2356 - accuracy: 0.5264 - top_k_categorical_accuracy: 0.8236 - val_loss: 0.0067 - val_macro_f1: 0.2164 - val_accuracy: 0.4741 - val_top_k_categorical_accuracy: 0.7639
# Epoch 21/40
# 52/52 [==============================] - 22s 413ms/step - loss: 0.0057 - macro_f1: 0.2542 - accuracy: 0.5446 - top_k_categorical_accuracy: 0.8419 - val_loss: 0.0066 - val_macro_f1: 0.2254 - val_accuracy: 0.4782 - val_top_k_categorical_accuracy: 0.7695
# Epoch 22/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0054 - macro_f1: 0.2779 - accuracy: 0.5618 - top_k_categorical_accuracy: 0.8529 - val_loss: 0.0066 - val_macro_f1: 0.2352 - val_accuracy: 0.4815 - val_top_k_categorical_accuracy: 0.7748
# Epoch 23/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0052 - macro_f1: 0.2861 - accuracy: 0.5841 - top_k_categorical_accuracy: 0.8645 - val_loss: 0.0065 - val_macro_f1: 0.2431 - val_accuracy: 0.4912 - val_top_k_categorical_accuracy: 0.7756
# Epoch 24/40
# 52/52 [==============================] - 21s 411ms/step - loss: 0.0051 - macro_f1: 0.3011 - accuracy: 0.6021 - top_k_categorical_accuracy: 0.8752 - val_loss: 0.0065 - val_macro_f1: 0.2468 - val_accuracy: 0.4939 - val_top_k_categorical_accuracy: 0.7803
# Epoch 25/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0049 - macro_f1: 0.3167 - accuracy: 0.6197 - top_k_categorical_accuracy: 0.8837 - val_loss: 0.0065 - val_macro_f1: 0.2544 - val_accuracy: 0.4967 - val_top_k_categorical_accuracy: 0.7815
# Epoch 26/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0047 - macro_f1: 0.3289 - accuracy: 0.6323 - top_k_categorical_accuracy: 0.8932 - val_loss: 0.0064 - val_macro_f1: 0.2617 - val_accuracy: 0.5014 - val_top_k_categorical_accuracy: 0.7845
# Epoch 27/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0046 - macro_f1: 0.3456 - accuracy: 0.6472 - top_k_categorical_accuracy: 0.9032 - val_loss: 0.0064 - val_macro_f1: 0.2699 - val_accuracy: 0.5062 - val_top_k_categorical_accuracy: 0.7869
# Epoch 28/40
# 52/52 [==============================] - 22s 417ms/step - loss: 0.0044 - macro_f1: 0.3572 - accuracy: 0.6669 - top_k_categorical_accuracy: 0.9110 - val_loss: 0.0064 - val_macro_f1: 0.2740 - val_accuracy: 0.5076 - val_top_k_categorical_accuracy: 0.7859
# Epoch 29/40
# 52/52 [==============================] - 22s 413ms/step - loss: 0.0043 - macro_f1: 0.3751 - accuracy: 0.6778 - top_k_categorical_accuracy: 0.9173 - val_loss: 0.0063 - val_macro_f1: 0.2772 - val_accuracy: 0.5103 - val_top_k_categorical_accuracy: 0.7892
# Epoch 30/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0041 - macro_f1: 0.3832 - accuracy: 0.6943 - top_k_categorical_accuracy: 0.9255 - val_loss: 0.0063 - val_macro_f1: 0.2818 - val_accuracy: 0.5138 - val_top_k_categorical_accuracy: 0.7863
# Epoch 31/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0040 - macro_f1: 0.3947 - accuracy: 0.7063 - top_k_categorical_accuracy: 0.9319 - val_loss: 0.0063 - val_macro_f1: 0.2904 - val_accuracy: 0.5099 - val_top_k_categorical_accuracy: 0.7831
# Epoch 32/40
# 52/52 [==============================] - 21s 411ms/step - loss: 0.0038 - macro_f1: 0.4091 - accuracy: 0.7210 - top_k_categorical_accuracy: 0.9356 - val_loss: 0.0064 - val_macro_f1: 0.2878 - val_accuracy: 0.5133 - val_top_k_categorical_accuracy: 0.7881
# Epoch 33/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0037 - macro_f1: 0.4230 - accuracy: 0.7321 - top_k_categorical_accuracy: 0.9426 - val_loss: 0.0064 - val_macro_f1: 0.2935 - val_accuracy: 0.5211 - val_top_k_categorical_accuracy: 0.7913
# Epoch 34/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0036 - macro_f1: 0.4368 - accuracy: 0.7458 - top_k_categorical_accuracy: 0.9476 - val_loss: 0.0063 - val_macro_f1: 0.2951 - val_accuracy: 0.5177 - val_top_k_categorical_accuracy: 0.7889
# Epoch 35/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0034 - macro_f1: 0.4459 - accuracy: 0.7595 - top_k_categorical_accuracy: 0.9515 - val_loss: 0.0063 - val_macro_f1: 0.2971 - val_accuracy: 0.5226 - val_top_k_categorical_accuracy: 0.7904
# Epoch 36/40
# 52/52 [==============================] - 22s 415ms/step - loss: 0.0033 - macro_f1: 0.4532 - accuracy: 0.7659 - top_k_categorical_accuracy: 0.9575 - val_loss: 0.0063 - val_macro_f1: 0.2996 - val_accuracy: 0.5187 - val_top_k_categorical_accuracy: 0.7933
# Epoch 37/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0032 - macro_f1: 0.4724 - accuracy: 0.7846 - top_k_categorical_accuracy: 0.9619 - val_loss: 0.0064 - val_macro_f1: 0.3048 - val_accuracy: 0.5227 - val_top_k_categorical_accuracy: 0.7903
# Epoch 38/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0031 - macro_f1: 0.4821 - accuracy: 0.7928 - top_k_categorical_accuracy: 0.9651 - val_loss: 0.0065 - val_macro_f1: 0.2986 - val_accuracy: 0.5221 - val_top_k_categorical_accuracy: 0.7881
# Epoch 39/40
# 52/52 [==============================] - 21s 413ms/step - loss: 0.0029 - macro_f1: 0.4871 - accuracy: 0.8066 - top_k_categorical_accuracy: 0.9687 - val_loss: 0.0065 - val_macro_f1: 0.3041 - val_accuracy: 0.5196 - val_top_k_categorical_accuracy: 0.7886
# Epoch 40/40
# 52/52 [==============================] - 22s 414ms/step - loss: 0.0028 - macro_f1: 0.5018 - accuracy: 0.8193 - top_k_categorical_accuracy: 0.9713 - val_loss: 0.0065 - val_macro_f1: 0.3062 - val_accuracy: 0.5188 - val_top_k_categorical_accuracy: 0.7918

# %%
top5_acc = history.history['top_k_categorical_accuracy']
val_top5_acc = history.history['val_top_k_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, top5_acc, label='Training top 5 accuracy')
plt.plot(epochs_range, val_top5_acc, label='Validation top 5 accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation top 5 accuracies')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training accuracy')
plt.plot(epochs_range, val_acc, label='Validation accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation accuracies')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
mf1 = history.history['macro_f1']
val_mf1 = history.history['val_macro_f1']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, mf1, label='Training macro f1')
plt.plot(epochs_range, val_mf1, label='Validation macro f1')
plt.legend(loc='lower right')
plt.title('Training and Validation macro f1')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
Result = model.evaluate(test_ds)
# Out:
#  8/22 [=========>....................] - ETA: 9:09 - loss: 0.0064 - macro_f1: 0.3200 - accuracy: 0.5256 - top_k_categorical_accuracy: 0.7969

# %%
def show_prediction(model, img_path, df_target):

    # Read and prepare image
    img = image.load_img(img_path, target_size=(IMG_SIZE,IMG_SIZE,CHANNELS))
    img = image.img_to_array(img)
    img = img/255
    img = np.expand_dims(img, axis=0)

    # Generate prediction
    prediction = (model.predict(img) > 0.5).astype('int')
    print(prediction)
    prediction = pd.Series(prediction[0])
    prediction.index = lb.classes_
    prediction = prediction[prediction==1].index.values
    print(prediction)

    class_description ="Not Found"

    #Get the class description of the bird
    if prediction[0] != "" :
      class_description = df_target.loc[df_target['class_id']== prediction[0]]['class_description'].iloc[0]
    else:
      prediction = "Not Found"


    # Dispaly image with prediction
    style.use('default')
    plt.figure(figsize=(8,4))
    plt.imshow(Image.open(img_path))
    plt.title('\nPrediction\n{}\n'.format(list(prediction)), fontsize=9)
    plt.title('\nBird class\n{}\n'.format(class_description), fontsize=9)
    plt.show()

# %% [markdown]
# # **Birds Classification from TensorFlow Hub**

# %% [markdown]
# https://tfhub.dev/google/aiy/vision/classifier/birds_V1/1

# %%
feature_extractor_url = "https://tfhub.dev/google/aiy/vision/classifier/birds_V1/1"
feature_extractor_layer = hub.KerasLayer(feature_extractor_url, trainable=False,
                                         input_shape=(IMG_SIZE,IMG_SIZE,CHANNELS))

# %%
model = tf.keras.Sequential([
    feature_extractor_layer,
    layers.Dense(2048, activation='relu', name='hidden_layer1'),
    layers.Dropout(0.4),
    layers.Dense(1024, activation='relu', name='hidden_layer2'),
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu', name='hidden_layer3'),
    layers.Dense(N_CLASSES, activation='softmax', name='output')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 965)               0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 2048)              1978368
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 512)               524800
# _________________________________________________________________
# output (Dense)               (None, 453)               232389
# =================================================================
# Total params: 4,833,733
# Trainable params: 4,833,733
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 256
model.compile(
    optimizer=tf.keras.optimizers.Adam(lr=5e-4),
    loss=tf.keras.metrics.binary_crossentropy,
    metrics=[macro_f1, 'accuracy', tf.keras.metrics.TopKCategoricalAccuracy()])   # Default is k = 5
    
history = model.fit(train_ds, epochs=40,batch_size = batch_size, validation_data = val_ds,
                             validation_batch_size = batch_size)
# Out:
# Epoch 1/40
# 52/52 [==============================] - 1578s 30s/step - loss: 0.3998 - macro_f1: 0.0000e+00 - accuracy: 0.0024 - top_k_categorical_accuracy: 0.0136 - val_loss: 0.0293 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0033 - val_top_k_categorical_accuracy: 0.0112
# Epoch 2/40
# 52/52 [==============================] - 25s 482ms/step - loss: 0.0223 - macro_f1: 0.0000e+00 - accuracy: 0.0030 - top_k_categorical_accuracy: 0.0145 - val_loss: 0.0164 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0023 - val_top_k_categorical_accuracy: 0.0130
# Epoch 3/40
# 52/52 [==============================] - 25s 484ms/step - loss: 0.0163 - macro_f1: 0.0000e+00 - accuracy: 0.0035 - top_k_categorical_accuracy: 0.0162 - val_loss: 0.0159 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0017 - val_top_k_categorical_accuracy: 0.0180
# Epoch 4/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0159 - macro_f1: 0.0000e+00 - accuracy: 0.0049 - top_k_categorical_accuracy: 0.0213 - val_loss: 0.0157 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0053 - val_top_k_categorical_accuracy: 0.0303
# Epoch 5/40
# 52/52 [==============================] - 25s 482ms/step - loss: 0.0158 - macro_f1: 0.0000e+00 - accuracy: 0.0067 - top_k_categorical_accuracy: 0.0261 - val_loss: 0.0156 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0112 - val_top_k_categorical_accuracy: 0.0353
# Epoch 6/40
# 52/52 [==============================] - 25s 483ms/step - loss: 0.0157 - macro_f1: 0.0000e+00 - accuracy: 0.0085 - top_k_categorical_accuracy: 0.0337 - val_loss: 0.0155 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0123 - val_top_k_categorical_accuracy: 0.0322
# Epoch 7/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0156 - macro_f1: 0.0000e+00 - accuracy: 0.0155 - top_k_categorical_accuracy: 0.0507 - val_loss: 0.0154 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0191 - val_top_k_categorical_accuracy: 0.0560
# Epoch 8/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0155 - macro_f1: 0.0000e+00 - accuracy: 0.0224 - top_k_categorical_accuracy: 0.0690 - val_loss: 0.0153 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0317 - val_top_k_categorical_accuracy: 0.0911
# Epoch 9/40
# 52/52 [==============================] - 25s 482ms/step - loss: 0.0154 - macro_f1: 0.0000e+00 - accuracy: 0.0400 - top_k_categorical_accuracy: 0.1068 - val_loss: 0.0152 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.0726 - val_top_k_categorical_accuracy: 0.1366
# Epoch 10/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0152 - macro_f1: 0.0000e+00 - accuracy: 0.0714 - top_k_categorical_accuracy: 0.1655 - val_loss: 0.0149 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.1333 - val_top_k_categorical_accuracy: 0.2317
# Epoch 11/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0149 - macro_f1: 0.0000e+00 - accuracy: 0.1302 - top_k_categorical_accuracy: 0.2606 - val_loss: 0.0145 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.2524 - val_top_k_categorical_accuracy: 0.3943
# Epoch 12/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0144 - macro_f1: 0.0000e+00 - accuracy: 0.2186 - top_k_categorical_accuracy: 0.3869 - val_loss: 0.0136 - val_macro_f1: 0.0000e+00 - val_accuracy: 0.3538 - val_top_k_categorical_accuracy: 0.5412
# Epoch 13/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0132 - macro_f1: 2.1239e-05 - accuracy: 0.3095 - top_k_categorical_accuracy: 0.5048 - val_loss: 0.0116 - val_macro_f1: 8.9432e-04 - val_accuracy: 0.4977 - val_top_k_categorical_accuracy: 0.6917
# Epoch 14/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0111 - macro_f1: 0.0062 - accuracy: 0.4423 - top_k_categorical_accuracy: 0.6527 - val_loss: 0.0089 - val_macro_f1: 0.0410 - val_accuracy: 0.6096 - val_top_k_categorical_accuracy: 0.8109
# Epoch 15/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0086 - macro_f1: 0.0648 - accuracy: 0.5720 - top_k_categorical_accuracy: 0.7818 - val_loss: 0.0067 - val_macro_f1: 0.1831 - val_accuracy: 0.6630 - val_top_k_categorical_accuracy: 0.8664
# Epoch 16/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0068 - macro_f1: 0.1902 - accuracy: 0.6399 - top_k_categorical_accuracy: 0.8571 - val_loss: 0.0054 - val_macro_f1: 0.2878 - val_accuracy: 0.6764 - val_top_k_categorical_accuracy: 0.8934
# Epoch 17/40
# 52/52 [==============================] - 25s 479ms/step - loss: 0.0056 - macro_f1: 0.2797 - accuracy: 0.6690 - top_k_categorical_accuracy: 0.8884 - val_loss: 0.0047 - val_macro_f1: 0.3385 - val_accuracy: 0.6837 - val_top_k_categorical_accuracy: 0.9066
# Epoch 18/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0050 - macro_f1: 0.3311 - accuracy: 0.6800 - top_k_categorical_accuracy: 0.9044 - val_loss: 0.0043 - val_macro_f1: 0.3735 - val_accuracy: 0.6899 - val_top_k_categorical_accuracy: 0.9125
# Epoch 19/40
# 52/52 [==============================] - 25s 482ms/step - loss: 0.0045 - macro_f1: 0.3673 - accuracy: 0.6923 - top_k_categorical_accuracy: 0.9135 - val_loss: 0.0040 - val_macro_f1: 0.3855 - val_accuracy: 0.6955 - val_top_k_categorical_accuracy: 0.9187
# Epoch 20/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0042 - macro_f1: 0.3849 - accuracy: 0.6991 - top_k_categorical_accuracy: 0.9220 - val_loss: 0.0038 - val_macro_f1: 0.4045 - val_accuracy: 0.6991 - val_top_k_categorical_accuracy: 0.9214
# Epoch 21/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0039 - macro_f1: 0.4018 - accuracy: 0.7031 - top_k_categorical_accuracy: 0.9265 - val_loss: 0.0037 - val_macro_f1: 0.4066 - val_accuracy: 0.6984 - val_top_k_categorical_accuracy: 0.9254
# Epoch 22/40
# 52/52 [==============================] - 25s 478ms/step - loss: 0.0038 - macro_f1: 0.4097 - accuracy: 0.7118 - top_k_categorical_accuracy: 0.9304 - val_loss: 0.0036 - val_macro_f1: 0.4122 - val_accuracy: 0.7079 - val_top_k_categorical_accuracy: 0.9277
# Epoch 23/40
# 52/52 [==============================] - 25s 483ms/step - loss: 0.0036 - macro_f1: 0.4138 - accuracy: 0.7114 - top_k_categorical_accuracy: 0.9346 - val_loss: 0.0036 - val_macro_f1: 0.4156 - val_accuracy: 0.7113 - val_top_k_categorical_accuracy: 0.9290
# Epoch 24/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0035 - macro_f1: 0.4202 - accuracy: 0.7141 - top_k_categorical_accuracy: 0.9390 - val_loss: 0.0035 - val_macro_f1: 0.4196 - val_accuracy: 0.7105 - val_top_k_categorical_accuracy: 0.9319
# Epoch 25/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0035 - macro_f1: 0.4210 - accuracy: 0.7151 - top_k_categorical_accuracy: 0.9395 - val_loss: 0.0034 - val_macro_f1: 0.4148 - val_accuracy: 0.7134 - val_top_k_categorical_accuracy: 0.9328
# Epoch 26/40
# 52/52 [==============================] - 25s 479ms/step - loss: 0.0034 - macro_f1: 0.4287 - accuracy: 0.7185 - top_k_categorical_accuracy: 0.9436 - val_loss: 0.0034 - val_macro_f1: 0.4262 - val_accuracy: 0.7134 - val_top_k_categorical_accuracy: 0.9330
# Epoch 27/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0033 - macro_f1: 0.4279 - accuracy: 0.7208 - top_k_categorical_accuracy: 0.9435 - val_loss: 0.0034 - val_macro_f1: 0.4304 - val_accuracy: 0.7134 - val_top_k_categorical_accuracy: 0.9345
# Epoch 28/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0032 - macro_f1: 0.4319 - accuracy: 0.7202 - top_k_categorical_accuracy: 0.9453 - val_loss: 0.0034 - val_macro_f1: 0.4242 - val_accuracy: 0.7150 - val_top_k_categorical_accuracy: 0.9348
# Epoch 29/40
# 52/52 [==============================] - 25s 478ms/step - loss: 0.0032 - macro_f1: 0.4351 - accuracy: 0.7259 - top_k_categorical_accuracy: 0.9495 - val_loss: 0.0033 - val_macro_f1: 0.4300 - val_accuracy: 0.7179 - val_top_k_categorical_accuracy: 0.9352
# Epoch 30/40
# 52/52 [==============================] - 25s 479ms/step - loss: 0.0031 - macro_f1: 0.4370 - accuracy: 0.7265 - top_k_categorical_accuracy: 0.9506 - val_loss: 0.0033 - val_macro_f1: 0.4292 - val_accuracy: 0.7157 - val_top_k_categorical_accuracy: 0.9368
# Epoch 31/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0031 - macro_f1: 0.4423 - accuracy: 0.7308 - top_k_categorical_accuracy: 0.9516 - val_loss: 0.0033 - val_macro_f1: 0.4323 - val_accuracy: 0.7213 - val_top_k_categorical_accuracy: 0.9368
# Epoch 32/40
# 52/52 [==============================] - 25s 480ms/step - loss: 0.0030 - macro_f1: 0.4404 - accuracy: 0.7319 - top_k_categorical_accuracy: 0.9537 - val_loss: 0.0033 - val_macro_f1: 0.4352 - val_accuracy: 0.7190 - val_top_k_categorical_accuracy: 0.9384
# Epoch 33/40
# 52/52 [==============================] - 25s 479ms/step - loss: 0.0030 - macro_f1: 0.4442 - accuracy: 0.7331 - top_k_categorical_accuracy: 0.9543 - val_loss: 0.0032 - val_macro_f1: 0.4377 - val_accuracy: 0.7194 - val_top_k_categorical_accuracy: 0.9387
# Epoch 34/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0030 - macro_f1: 0.4406 - accuracy: 0.7334 - top_k_categorical_accuracy: 0.9570 - val_loss: 0.0032 - val_macro_f1: 0.4408 - val_accuracy: 0.7197 - val_top_k_categorical_accuracy: 0.9386
# Epoch 35/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0030 - macro_f1: 0.4494 - accuracy: 0.7330 - top_k_categorical_accuracy: 0.9555 - val_loss: 0.0032 - val_macro_f1: 0.4365 - val_accuracy: 0.7243 - val_top_k_categorical_accuracy: 0.9396
# Epoch 36/40
# 52/52 [==============================] - 25s 478ms/step - loss: 0.0029 - macro_f1: 0.4473 - accuracy: 0.7346 - top_k_categorical_accuracy: 0.9590 - val_loss: 0.0032 - val_macro_f1: 0.4397 - val_accuracy: 0.7238 - val_top_k_categorical_accuracy: 0.9398
# Epoch 37/40
# 52/52 [==============================] - 25s 478ms/step - loss: 0.0029 - macro_f1: 0.4517 - accuracy: 0.7370 - top_k_categorical_accuracy: 0.9575 - val_loss: 0.0032 - val_macro_f1: 0.4396 - val_accuracy: 0.7235 - val_top_k_categorical_accuracy: 0.9406
# Epoch 38/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0028 - macro_f1: 0.4480 - accuracy: 0.7370 - top_k_categorical_accuracy: 0.9599 - val_loss: 0.0032 - val_macro_f1: 0.4415 - val_accuracy: 0.7251 - val_top_k_categorical_accuracy: 0.9406
# Epoch 39/40
# 52/52 [==============================] - 25s 479ms/step - loss: 0.0028 - macro_f1: 0.4507 - accuracy: 0.7380 - top_k_categorical_accuracy: 0.9614 - val_loss: 0.0032 - val_macro_f1: 0.4406 - val_accuracy: 0.7249 - val_top_k_categorical_accuracy: 0.9395
# Epoch 40/40
# 52/52 [==============================] - 25s 481ms/step - loss: 0.0028 - macro_f1: 0.4527 - accuracy: 0.7397 - top_k_categorical_accuracy: 0.9626 - val_loss: 0.0032 - val_macro_f1: 0.4422 - val_accuracy: 0.7270 - val_top_k_categorical_accuracy: 0.9393

# %%
top5_acc = history.history['top_k_categorical_accuracy']
val_top5_acc = history.history['val_top_k_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, top5_acc, label='Training top 5 accuracy')
plt.plot(epochs_range, val_top5_acc, label='Validation top 5 accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation top 5 accuracies')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training accuracy')
plt.plot(epochs_range, val_acc, label='Validation accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation accuracies')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
mf1 = history.history['macro_f1']
val_mf1 = history.history['val_macro_f1']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(40)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, mf1, label='Training macro f1')
plt.plot(epochs_range, val_mf1, label='Validation macro f1')
plt.legend(loc='lower right')
plt.title('Training and Validation macro f1')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
Result = model.evaluate(test_ds)
# Out:
#  9/22 [===========>..................] - ETA: 5:21 - loss: 0.0032 - macro_f1: 0.4424 - accuracy: 0.7255 - top_k_categorical_accuracy: 0.9414

# %% [markdown]
# # **Conclusions**:
#
# Until now, all the models we have built came from "TensorFlow Hub/Image Problem Domains/Feature Vector" where we were working on models prepared for feature vector tasks. In this project, I tested a model related to image classification task which was trained on a birds image dataset. As a conclusion, the image classification MobileNet V2 model **"aiy/vision/classifier/birds_V1"** located at "TensorFlow Hub/Image Problem Domains/Classification" worked much better on my big part of the dataset which includes 453 classes and 43955 images. Although the memory crashed on the last coding cell written above, the plots indicate that this pre-trained model is expected to give us the following result:
#
# * **Validation Accuracy: 72.5%**
# * **Validation Top 5 Accuracy: 94%**
# * **Macro F1 Score: 44%**
#
# In this model, the training and validation performances are almost the same!
